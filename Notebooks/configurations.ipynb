# %%
from pathlib import Path
###################################################################
# DEFAULT DIRECTORIES
###################################################################
# Default output directory
DEFAULT_OUTPUT_DIR = Path("output")
# Default input directory
#DEFAULT_INPUT_DIR = Path("input")

# To reproduce evaluation results, set the input directory to the following path
#DEFAULT_INPUT_DIR = Path("evaluation_paper", "data_collection", "datasets_evaluation")
DEFAULT_INPUT_DIR = Path("input")

###################################################################
# HYPER-PARAMETERS
###################################################################
# STEP 1: Change point detection technique used in Step 1
STEP1 = {'method': 'process_graphs'}

# To obtain evaluation results of Step 1 for other techniques, replace use one of the following options:
# 'emd', 'prodrift', 'zheng', 'bose_j', 'process_graphs', 'lcdd', 'adwin_j'

# STEP 2: Change type classification
CONSTANT_ALPHA = 3

# STEP 3: Change interrelation analysis
SIMILARITY = 'cosine'
INCREMENTAL_DRIFT_PAR = 80
RECURRING_DRIFT_PAR = 95
